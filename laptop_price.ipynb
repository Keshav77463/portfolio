# %%
import numpy as np
import pandas as pd

# %%
laptop=pd.read_csv('/content/laptop_data.csv')

# %%
laptop.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
laptop.drop(columns=['Unnamed: 0'])
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
laptop['Weight'] = laptop['Weight'].astype(str).str.replace('kg', '').astype(float)

# %%
laptop['Ram']=laptop['Ram'].str.replace('GB','').astype('int32')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(laptop['Price'])
# Out:
# /tmp/ipython-input-4032248244.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(laptop['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
laptop['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=laptop['Company'],y=laptop['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
laptop['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=laptop['TypeName'],y=laptop['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=laptop['Inches'],y=laptop['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
laptop['Touchscreen']=laptop['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
sns.barplot(x=laptop['Touchscreen'],y=laptop['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
laptop['ips']=laptop['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
laptop.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
laptop['ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ips'>

# %%
new=laptop['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
laptop['X_res']=new[0]
laptop['y_res']=new[1]

# %%
laptop.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
laptop['X_res'] = laptop['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
laptop.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
laptop['X_res'] = laptop['X_res'].astype('int32')
laptop['y_res'] = laptop['y_res'].astype('int32')

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float64
#  11  Price             1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  ips               1303 non-null   int64
#  14  X_res             1303 non-null   int32
#  15  y_res             1303 non-null   int32
# ...

# %%
laptop.corr(numeric_only=True)['Price']
# Out:
# Unnamed: 0     0.067984
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# ips            0.252208
# X_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
laptop['ppi'] = (((laptop['X_res']**2) + (laptop['y_res']**2))**0.5/laptop['Inches']).astype('float')

# %%
laptop.drop(columns=['Inches','X_res','y_res','Unnamed: 0','ScreenResolution'],inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
laptop['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
laptop['Cpu name']=laptop['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu name
# ...

# %%
def fetch_processor(text):
  if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
     return text
  else:
      if text.split()[0]=='Intel':
        return 'Other Intel Processor'

      else:
        return 'AMD Processor'

# %%
laptop['Cpu brand'] = laptop['Cpu name'].apply(fetch_processor)

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu name      Cpu brand
# ...

# %%
laptop['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
 sns.barplot(x=laptop["Cpu brand"],y=laptop["Price"])
 plt.xticks(rotation='vertical')
 plt.show()

# %%
 sns.barplot(x=laptop["Ram"],y=laptop["Price"])
 plt.xticks(rotation='vertical')
 plt.show()

# %%
laptop['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
# Clean .0 properly
laptop['Memory'] = laptop['Memory'].astype(str).replace(r'\.0', '', regex=True)

# Remove GB, replace TB with 000
laptop['Memory'] = laptop['Memory'].str.replace('GB', '', regex=False)
laptop['Memory'] = laptop['Memory'].str.replace('TB', '000', regex=False)

# Split into two parts
new = laptop['Memory'].str.split("+", n=1, expand=True)
laptop['first'] = new[0].str.strip()
laptop['second'] = new[1].fillna("0").str.strip()

# Detect storage type BEFORE removing text
laptop["Layer1HDD"] = laptop["first"].apply(lambda x: 1 if "HDD" in x else 0)
laptop["Layer1SSD"] = laptop["first"].apply(lambda x: 1 if "SSD" in x else 0)
laptop["Layer1Hybrid"] = laptop["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
laptop["Layer1Flash_Storage"] = laptop["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

laptop["Layer2HDD"] = laptop["second"].apply(lambda x: 1 if "HDD" in x else 0)
laptop["Layer2SSD"] = laptop["second"].apply(lambda x: 1 if "SSD" in x else 0)
laptop["Layer2Hybrid"] = laptop["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
laptop["Layer2Flash_Storage"] = laptop["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Now remove non-digits for numeric extraction
laptop['first'] = laptop['first'].str.replace(r'\D', '', regex=True)
laptop['second'] = laptop['second'].str.replace(r'\D', '', regex=True)

# Convert to integers safely
laptop["first"] = laptop["first"].replace('', '0').astype(int)
laptop["second"] = laptop["second"].replace('', '0').astype(int)

# Final numeric storage columns
laptop["HDD"] = laptop["first"]*laptop["Layer1HDD"] + laptop["second"]*laptop["Layer2HDD"]
laptop["SSD"] = laptop["first"]*laptop["Layer1SSD"] + laptop["second"]*laptop["Layer2SSD"]
laptop["Hybrid"] = laptop["first"]*laptop["Layer1Hybrid"] + laptop["second"]*laptop["Layer2Hybrid"]
laptop["Flash_Storage"] = laptop["first"]*laptop["Layer1Flash_Storage"] + laptop["second"]*laptop["Layer2Flash_Storage"]

# Drop helper columns
laptop.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
                     'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
                     'Layer2Flash_Storage'], inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
laptop.drop(columns=['Memory'],inplace=True)

# %%
laptop.corr(numeric_only=True)['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
laptop['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
laptop['Gpu brand']=laptop['Gpu'].apply(lambda x:x.split()[0])

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu name      Cpu brand  HDD  SSD  Hybrid  Flash_Storage  \
# 0  226.983005  Intel Core i5  Intel Core i5    0  128       0              0
# ...

# %%
laptop['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
laptop[laptop['Gpu brand'] != 'ARM']
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
laptop.drop(columns=['Gpu'],inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram  OpSys  Weight  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8  macOS    1.37
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  macOS    1.34
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8  No OS    1.86
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16  macOS    1.83
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8  macOS    1.37
#
#          Price  Touchscreen  ips         ppi       Cpu name      Cpu brand  \
# 0   71378.6832            0    1  226.983005  Intel Core i5  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5  Intel Core i5
# 2   30636.0000            0    0  141.211998  Intel Core i5  Intel Core i5
# 3  135195.3360            0    1  220.534624  Intel Core i7  Intel Core i7
# 4   96095.8080            0    1  226.983005  Intel Core i5  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage Gpu brand
# 0    0  128       0              0     Intel
# ...

# %%
def cat_os(inp):
  if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
  elif inp == 'macOs' or inp=='Mac OS X':
      return 'Mac'
  else:
       return 'others/no os/linux'

# %%
laptop['os']=laptop['OpSys'].apply(cat_os)

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram  OpSys  Weight  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8  macOS    1.37
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  macOS    1.34
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8  No OS    1.86
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16  macOS    1.83
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8  macOS    1.37
#
#          Price  Touchscreen  ips         ppi       Cpu name      Cpu brand  \
# 0   71378.6832            0    1  226.983005  Intel Core i5  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5  Intel Core i5
# 2   30636.0000            0    0  141.211998  Intel Core i5  Intel Core i5
# 3  135195.3360            0    1  220.534624  Intel Core i7  Intel Core i7
# 4   96095.8080            0    1  226.983005  Intel Core i5  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage Gpu brand                  os
# ...

# %%
laptop.drop(columns=['OpSys'],inplace=True)

# %%
laptop.head()
# Out:
#   Company   TypeName                         Cpu  Ram  Weight        Price  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8    1.37   71378.6832
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8    1.34   47895.5232
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8    1.86   30636.0000
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16    1.83  135195.3360
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8    1.37   96095.8080
#
#    Touchscreen  ips         ppi       Cpu name      Cpu brand  HDD  SSD  \
# 0            0    1  226.983005  Intel Core i5  Intel Core i5    0  128
# 1            0    0  127.677940  Intel Core i5  Intel Core i5    0    0
# 2            0    0  141.211998  Intel Core i5  Intel Core i5    0  256
# 3            0    1  220.534624  Intel Core i7  Intel Core i7    0  512
# 4            0    1  226.983005  Intel Core i5  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage Gpu brand                  os
# ...

# %%
sns.barplot(x=laptop['os'],y=laptop['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.heatmap(laptop.corr(numeric_only=True))
plt.show()

# %%
sns.distplot(np.log(laptop['Price']))
# Out:
# /tmp/ipython-input-3984844542.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(laptop['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X=laptop.drop(columns=['Price','Cpu','Cpu name'])
y=np.log(laptop['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1107 entries, 183 to 1192
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1107 non-null   object
#  1   TypeName       1107 non-null   object
#  2   Ram            1107 non-null   int32
#  3   Weight         1107 non-null   float64
#  4   Touchscreen    1107 non-null   int64
#  5   ips            1107 non-null   int64
#  6   ppi            1107 non-null   float64
#  7   Cpu brand      1107 non-null   object
#  8   HDD            1107 non-null   int64
#  9   SSD            1107 non-null   int64
#  10  Hybrid         1107 non-null   int64
#  11  Flash_Storage  1107 non-null   int64
#  12  Gpu brand      1107 non-null   object
#  13  os             1107 non-null   object
# dtypes: float64(2), int32(1), int64(6), object(5)
# memory usage: 125.4+ KB

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = XGBRegressor(n_estimators=45, max_depth=5, learning_rate=0.5)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8975484080643825
# MAE: 0.15829376093218608

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = RandomForestRegressor()
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8843787819559539
# MAE: 0.1558026675087637

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8244775818150178
# MAE: 0.21036061605680598

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8350740849020124
# MAE: 0.19195656946706496

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8397352276492465
# MAE: 0.1902185047078194

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = SVR(kernel='rbf')

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.6941035895562366
# MAE: 0.27724005010876596

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = step2=AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8000733376660327
# MAE: 0.2224759786427956

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

step2 = step2=GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8865244095875732
# MAE: 0.16400343346382004

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# All categorical columns by index
categorical_cols = [0, 1, 7, 12, 13]

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(bootstrap=True,n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10)


step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])


pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8913248566476937
# MAE: 0.15701550385077925
